# %% [markdown]
# # Hipóteses

# %% [markdown]
# - Redes mais densas são mais resilientes a falhas aleatórias, mas mais vulneráveis a ataques direcionados
#
# - Nós com alta centralidade são pontos críticos
#
# - Falhas em hubs causam maior impacto sistêmico
