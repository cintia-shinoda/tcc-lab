# %% [markdown]
# # Artigos

# %% [markdown]
# | # | Artigo | Ano | Observações |
# |:---:|:-------|:---:|:--------|
# | 1 | Massobrio et al. — "Topological assessment of recoverability in public transport networks" (Communications Physics, Nature) | 2024 | Resiliência de 42 redes de metrô usando métricas topológicas. Direto no tema da sua P1. |
# | 2 | Zhang et al. — "Vulnerability of urban rail transit network" (Chongqing) (PMC/Sustainability) | 2024 | Usa degree, betweenness + K-means pra classificar nós críticos. Mesma abordagem que a sua. |
# | 3 | Fortin et al. — "Innovative GTFS Data Application for Transit Network Analysis Using a Graph-Oriented Method" (J. Public Transportation) | 2022 | Usa GTFS + grafos pra análise de rede — idêntico à sua metodologia. |
# | 4 | De Bona et al. — "Analysing the Vulnerability of Public Transport Networks" (ResearchGate) | 2021 | Compara ataque vs falha aleatória em redes de ônibus. Exatamente sua P1. |
# | 5 | Kim et al. — "Evaluation of Public Transportation System through Social Network Analysis Approach" (Sustainability) | 2024 | Usa centralidade pra identificar rotas ineficientes e equidade. Conecta P1 com P2. |
# | 1 | [Danilo Santana e Silva: "Modelagem do Transporte Urbano Através de Grafos"](https://www.ime.usp.br/~mapweb/tcc/2018/DaniloSantanaV1.pdf) | 2018 | <ul><li>Mesmo tema: rede de ônibus+metrô de SP modelada como grafo usando dados abertos.</li></ul> |
# | 2 | Sandro Ferreira Sousa: "[Estudo das propriedades e robustez da rede de transporte público de São Paulo](https://www.researchgate.net/publication/304946197_Estudo_das_propriedades_e_robustez_da_rede_de_transporte_publico_de_Sao_Paulo)" | 2016 | <ul><li>Rede de SP como rede complexa,</li><li>simulação de ataques</li><li>métricas de robustez</li></ul> |
# | 3 | Andre Borgato Morelli, André Luiz Cunha: ["Verificação de vulnerabilidades em redes de transporte: uma abordagem pela teoria dos grafos](https://www.researchgate.net/publication/335888909_Verificacao_de_vulnerabilidades_em_redes_de_transporte_uma_abordagem_pela_teoria_dos_grafos#fullTextFileContent)" | 2019 | <ul><li>Analisa 309 cidades brasileiras</li><li>betweenness é a melhor métrica pra vulnerabilidade</li></ul> |
# | 4 | Renzo Massobrio, Oded Cats "[Topological assessment of recoverability in public transport networks](https://www.nature.com/articles/s42005-024-01596-8)" (Nature Comms Physics) | 2024 | Resiliência de 42 redes de metrô. |
# | 5 | Jinghua Song, Jianfeng Ding, Xuechen Gui, Yuyi Zhu: "[Vulnerability of urban rail transit network](https://www.cell.com/heliyon/fulltext/S2405-8440(24)03268-7)" | 2024 | Degree + betweenness + K-means.  |
